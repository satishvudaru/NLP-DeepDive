# %%
mylist=[0,1,2]

# %%
print(f"The first no is :{mylist[0]}")
# Out:
# The first no is :0

# %%
library =[('Author','Topic','Pages'),('Twain','Rafting',601),('Mark','Rafting',701)]

# %%
for author,topic,pages in library:
    print (f"{author},{topic},{pages}")
# Out:
# Author,Topic,Pages
# Twain,Rafting,601
# Mark,Rafting,701

# %%
from datetime import datetime
today = datetime.now()
print(f"current day is:{today:%B, %Y}")
# Out:
# current day is:February, 2026

# %%
# %%writefile test.txt
# Hello, This is quick test file.
# This is the second line
# Out:
# Overwriting test.txt

# %%
with open("test.txt",mode="a+") as newfile:
    newfile.writelines("\nediting the file")
    newfile.seek(0)
    newfile.read()
