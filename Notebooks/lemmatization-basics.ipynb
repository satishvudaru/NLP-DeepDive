# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc1=nlp(u"I am runner running in a race because i love to run since i ran today")

for token in doc1:
    print (token.text,'\t',token.pos_,'\t',token.lemma,'\t',token.lemma_)
# Out:
# I 	 PRON 	 4690420944186131903 	 I
# am 	 AUX 	 10382539506755952630 	 be
# runner 	 NOUN 	 12640964157389618806 	 runner
# running 	 VERB 	 12767647472892411841 	 run
# in 	 ADP 	 3002984154512732771 	 in
# a 	 DET 	 11901859001352538922 	 a
# race 	 NOUN 	 8048469955494714898 	 race
# because 	 SCONJ 	 16950148841647037698 	 because
# i 	 PRON 	 4690420944186131903 	 I
# love 	 VERB 	 3702023516439754181 	 love
# to 	 PART 	 3791531372978436496 	 to
# run 	 VERB 	 12767647472892411841 	 run
# since 	 SCONJ 	 10066841407251338481 	 since
# i 	 PRON 	 4690420944186131903 	 I
# ran 	 VERB 	 12767647472892411841 	 run
# today 	 NOUN 	 11042482332948150395 	 today

# %%
print(nlp.Defaults.stop_words)
# Out:
# {"'ve", 'herself', 'wherein', 'else', 'where', 'yet', 'per', '’s', 'none', '’m', 'perhaps', 'whenever', 'is', 'because', 'herein', 'see', 'throughout', '’ll', 'namely', 'one', 'too', 'everyone', 'otherwise', 'back', 'well', 'please', 'until', 'together', 'everywhere', 'former', 'quite', 'hereby', 'most', 'yourself', 'and', 'next', 'every', 'or', 'did', 'ca', 'when', 'be', 'either', 'with', 'only', 'became', 'any', 'few', 'even', 'latterly', 'already', 'ourselves', 'eleven', 'forty', 'across', 'however', 'through', 'rather', 'also', 'ours', 'nobody', 'move', "'re", 'your', 'still', 'someone', 'therefore', 'whom', 'moreover', 'nowhere', 'formerly', 'made', 'last', 'so', 'whether', 'seems', 'anyone', 'under', 'about', 'using', 'they', 'here', 'himself', 'has', 'as', 'themselves', 'three', 'was', 'whose', '’d', 'upon', 'who', 'why', 'during', 'wherever', 'behind', 'them', 'cannot', 'anything', 'his', 'thereby', 'thru', 'would', 'yours', 'except', 'although', 'those', 'whole', 'again', 'of', 'but', 'around', 'due', '‘re', 'thence', 'myself', 'keep', 'whence', 'name', 'seeming', 'we', 'full', 'she', 'noone', 'becoming', 'into', 'six', 'somewhere', 'must', 'now', 'call', 'between', 'against', 'ten', 'first', 'nine', 'besides', 'am', 'no', 'these', 'put', 'my', 'are', 'before', 'by', 'doing', 'five', 'fifteen', '‘d', 'toward', 'thereupon', '‘s', 'least', 'front', 'sometimes', 'side', 'seemed', 'thus', 'he', 're', 'in', 'than', 'hereafter', 'then', 'our', 'us', 'beside', 'mine', 'such', 'make', 'get', 'over', 'among', 'above', 'meanwhile', 'there', 'some', 'part', 'should', 'n‘t', 'really', 'towards', 'four', 'will', 'could', 'while', "n't", "'s", 'via', 'have', 'ever', 'sometime', 'seem', 'not', 'if', 'each', 'a', 'never', 'hundred', 'say', 'take', 'had', 'afterwards', 'same', 'its', 'anywhere', 'me', 'to', 'along', 'which', 'out', 'sixty', 'were', 'though', 'it', 'that', 'somehow', 'whither', 'top', 'at', 'below', 'both', 'may', 'own', 'unless', 'everything', 'whereupon', 'nor', 'anyhow', 'whereas', 'an', 'nothing', 'whatever', 'within', 'other', 'from', 'might', 'after', 'done', 'empty', 'up', 'amongst', 'eight', 'whereafter', 'since', 'how', 'less', 'whoever', 'two', 'onto', 'hereupon', 'much', "'ll", 'elsewhere', 'give', 'this', '‘ve', 'does', "'m", '‘ll', 'yourselves', 'something', 'beforehand', 'on', 'further', 'go', 'show', 'n’t', 'indeed', 'becomes', 'been', "'d", '‘m', 'always', '’re', 'anyway', 'become', 'latter', 'often', 'enough', 'twenty', 'down', 'all', 'mostly', 'hers', 'i', 'whereby', 'hence', 'their', 'regarding', 'fifty', 'for', 'alone', 'others', 'bottom', 'third', 'nevertheless', 'just', 'various', 'what', 'off', 'another', 'several', 'once', 'therein', 'you', 'twelve', 'the', 'being', 'amount', 'more', 'thereafter', '’ve', 'him', 'almost', 'neither', 'her', 'used', 'many', 'can', 'do', 'serious', 'beyond', 'very', 'itself', 'without'}

# %% [markdown]
# #Phrase matching and vocabulary

# %%
from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)
